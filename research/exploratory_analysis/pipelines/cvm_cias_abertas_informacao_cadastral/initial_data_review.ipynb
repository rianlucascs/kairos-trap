# %% [markdown]
# # Revisão inicial, filtros, observações e análise exploratória

# %%
from pipelines.readers.pipelines.cvm_cias_abertas_informacao_cadastral.reader_parquet import ReaderSnapshotParquet as cias_abertas

# %%
df = cias_abertas().read()

# %%
df.tail(5)
# Out:
#                 CNPJ_CIA                              DENOM_SOCIAL  \
# 2672  13.574.594/0001-96                                 ZAMP S.A.
# 2673  71.320.931/0001-15                  ZANINI SA EQUIPS PESADOS
# 2674  24.744.012/0001-99                          ZH OPERAÇÕES S/A
# 2675  92.749.217/0001-17                         ZIVI SA CUTELARIA
# 2676  74.533.787/0001-93  ZOGBI LEASING S/A ARRENDAMENTO MERCANTIL
#
#           DENOM_COMERC     DT_REG   DT_CONST  DT_CANCEL  \
# 2672         ZAMP S.A. 2017-12-14 2011-04-06        NaT
# 2673            ZANINI 1971-07-05        NaT 1997-01-27
# 2674  ZH OPERAÇÕES S/A 2016-09-16 2016-04-15 2017-08-07
# 2675          ZIVI S/A 1968-11-01 1931-01-01 2003-12-29
# 2676     ZOGBI LEASING 1997-09-18 1993-06-18 2004-12-23
#
#                                          MOTIVO_CANCEL        SIT DT_INI_SIT  \
# 2672                                              <NA>      ATIVO 2017-12-14
# ...

# %%
df[["DENOM_SOCIAL", "DENOM_COMERC", "CNPJ_CIA", "CD_CVM", "SIT", "MOTIVO_CANCEL"]].tail(3)
# Out:
#                                   DENOM_SOCIAL      DENOM_COMERC  \
# 2674                          ZH OPERAÇÕES S/A  ZH OPERAÇÕES S/A
# 2675                         ZIVI SA CUTELARIA          ZIVI S/A
# 2676  ZOGBI LEASING S/A ARRENDAMENTO MERCANTIL     ZOGBI LEASING
#
#                 CNPJ_CIA CD_CVM        SIT  \
# 2674  24.744.012/0001-99  24007  CANCELADA
# 2675  92.749.217/0001-17  11843  CANCELADA
# 2676  74.533.787/0001-93  16462  CANCELADA
#
#                                          MOTIVO_CANCEL
# 2674                            CANCELAMENTO DE OFÍCIO
# 2675                           ELISÃO POR INCORPORAÇÃO
# 2676  ATENDIMENTO AS NORMAS DA INSTRUÇÃO CVM Nº 361/02

# %%
cols = ["DENOM_SOCIAL", "DENOM_COMERC", "CNPJ_CIA", "CD_CVM", "SIT", "MOTIVO_CANCEL"]

df_cias_ativo = df[df["SIT"] == "ATIVO"]

# %%
df_cias_ativo[cols]
# Out:
#                                            DENOM_SOCIAL  \
# 2     521 PARTICIPAÇOES S.A. - EM LIQUIDAÇÃO EXTRAJU...
# 3                                  524 PARTICIPAÇOES SA
# 13                              ACO VERDE DO BRASIL S.A
# 28                AEGEA SANEAMENTO E PARTICIPAÇÕES S.A.
# 29    AERIS IND. E COM. DE EQUIP. PARA GER. DE ENG. ...
# ...                                                 ...
# 2666                                  YBYRA CAPITAL S.A
# 2667                           YDUQS PARTICIPACOES S.A.
# 2668                           YDUQS PARTICIPACOES S.A.
# 2669           YOU INC INCORPORADORA E PARTICIPAÇÃO S.A
# 2672                                          ZAMP S.A.
#
#                                     DENOM_COMERC            CNPJ_CIA CD_CVM  \
# 2                          521 PARTICIPAÇÕES S/A  01.547.749/0001-16  16330
# 3                           524 PARTICIPACOES SA  01.851.771/0001-55  16284
# ...

# %%
print(len(df_cias_ativo))
# Out:
# 757

# %%
df[["SIT"]].value_counts()
# Out:
# SIT
# CANCELADA                    1912
# ATIVO                         757
# SUSPENSO(A) - DECISÃO ADM       8
# Name: count, dtype: int64

# %%
df[df["CNPJ_CIA"] == "01.547.749/0001-16"]
# Out:
#              CNPJ_CIA                                       DENOM_SOCIAL  \
# 2  01.547.749/0001-16  521 PARTICIPAÇOES S.A. - EM LIQUIDAÇÃO EXTRAJU...
#
#             DENOM_COMERC     DT_REG   DT_CONST DT_CANCEL MOTIVO_CANCEL    SIT  \
# 2  521 PARTICIPAÇÕES S/A 1997-07-11 1996-07-30       NaT          <NA>  ATIVO
#
#   DT_INI_SIT CD_CVM  ... UF_RESP PAIS_RESP CEP_RESP DDD_TEL_RESP TEL_RESP  \
# 2 1997-07-11  16330  ...    <NA>      <NA>     <NA>         <NA>     <NA>
#
#   DDD_FAX_RESP FAX_RESP EMAIL_RESP        CNPJ_AUDITOR  \
# 2         <NA>     <NA>       <NA>  02.878.522/0001-16
#
#                                         AUDITOR
# 2  IRKO HIRASHIMA AUDITORES INDEPENDENTES LTDA.
#
# [1 rows x 47 columns]

# %%
df[df["CD_CVM"] == "21032"]
# Out:
#               CNPJ_CIA       DENOM_SOCIAL  DENOM_COMERC     DT_REG   DT_CONST  \
# 71  71.208.516/0001-74  ALGAR TELECOM S/A  CTBC TELECOM 2007-07-27 2004-01-01
#
#    DT_CANCEL MOTIVO_CANCEL    SIT DT_INI_SIT CD_CVM  ... UF_RESP PAIS_RESP  \
# 71       NaT          <NA>  ATIVO 2007-07-27  21032  ...    <NA>      <NA>
#
#     CEP_RESP DDD_TEL_RESP  TEL_RESP DDD_FAX_RESP FAX_RESP       EMAIL_RESP  \
# 71  38400668           34  32562155         <NA>     <NA>  ri@algar.com.br
#
#           CNPJ_AUDITOR                                          AUDITOR
# 71  61.366.936/0001-25  ERNST & YOUNG AUDITORES INDEPENDENTES S/S LTDA.
#
# [1 rows x 47 columns]
