# %% [markdown]
# # Diagnóstico preliminar da qualidade dos dados, incluindo shape, nulos, tipos e duplicados.

# %%
from pipelines.readers.pipelines.cvm_formulario_informacoes_trimestrais.reader_parquet import ReaderSnapshotParquet as itr

# %%
df = itr().read("BPA_con")

# %%
df.shape
# Out:
# (2335382, 15)

# %%
df.tail(3)
# Out:
#                    CNPJ_CIA   DT_REFER  ...  ST_CONTA_FIXA ORIGEM_FORMULARIO
# 2335379  97.837.181/0001-47 2026-06-30  ...              N               ITR
# 2335380  97.837.181/0001-47 2026-06-30  ...              N               ITR
# 2335381  97.837.181/0001-47 2026-06-30  ...              N               ITR
#
# [3 rows x 15 columns]

# %%
df.isnull().sum()
# Out:
# CNPJ_CIA             0
# DT_REFER             0
# VERSAO               0
# DENOM_CIA            0
# CD_CVM               0
# GRUPO_DFP            0
# MOEDA                0
# ESCALA_MOEDA         0
# ORDEM_EXERC          0
# DT_FIM_EXERC         0
# CD_CONTA             0
# DS_CONTA             0
# VL_CONTA             0
# ST_CONTA_FIXA        0
# ORIGEM_FORMULARIO    0
# dtype: int64

# %%
df.dtypes
# Out:
# CNPJ_CIA             string[python]
# DT_REFER             datetime64[ns]
# VERSAO                        Int64
# DENOM_CIA            string[python]
# CD_CVM               string[python]
# GRUPO_DFP            string[python]
# MOEDA                string[python]
# ESCALA_MOEDA         string[python]
# ORDEM_EXERC          string[python]
# DT_FIM_EXERC         datetime64[ns]
# CD_CONTA             string[python]
# DS_CONTA             string[python]
# VL_CONTA                    float64
# ST_CONTA_FIXA        string[python]
# ORIGEM_FORMULARIO            object
# dtype: object

# %%
key_cols = df.columns.tolist()
duplicados = df[df.duplicated(subset=key_cols, keep=False)]
print(len(duplicados))
# Out:
# 7934

# %%
itr(demonstration_code='DRE_con').query_parquet(filters={"CD_CVM": 16330, "CD_CONTA": "3.01"}).tail(3)
# Out:
#              CNPJ_CIA   DT_REFER  VERSAO  \
# 7  01.547.749/0001-16 2011-09-30       1
# 8  01.547.749/0001-16 2011-09-30       1
# 9  01.547.749/0001-16 2011-09-30       1
#
#                                            DENOM_CIA  CD_CVM  \
# 7  521 PARTICIPACOES S.A. - EM LIQUIDAÇÃO EXTRAJU...  016330
# 8  521 PARTICIPACOES S.A. - EM LIQUIDAÇÃO EXTRAJU...  016330
# 9  521 PARTICIPACOES S.A. - EM LIQUIDAÇÃO EXTRAJU...  016330
#
#                                     GRUPO_DFP MOEDA ESCALA_MOEDA ORDEM_EXERC  \
# 7  DF Consolidado - Demonstração do Resultado  REAL          MIL   PENÚLTIMO
# 8  DF Consolidado - Demonstração do Resultado  REAL          MIL      ÚLTIMO
# 9  DF Consolidado - Demonstração do Resultado  REAL          MIL      ÚLTIMO
#
#   DT_INI_EXERC DT_FIM_EXERC CD_CONTA                                DS_CONTA  \
# 7   2010-07-01   2010-09-30     3.01  Receita de Venda de Bens e/ou Serviços
# 8   2011-01-01   2011-09-30     3.01  Receita de Venda de Bens e/ou Serviços
# ...
